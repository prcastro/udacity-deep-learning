# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, I'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()

vocab = set(text)
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
chars = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
chars[:100]
# Out:
# array([20, 76, 34, 44, 58, 17, 23, 40, 13, 69, 69, 69, 55, 34, 44, 44,  5,
#        40,  3, 34, 14, 71, 33, 71, 17, 79, 40, 34, 23, 17, 40, 34, 33, 33,
#        40, 34, 33, 71, 74, 17, 45, 40, 17,  8, 17, 23,  5, 40, 66, 59, 76,
#        34, 44, 44,  5, 40,  3, 34, 14, 71, 33,  5, 40, 71, 79, 40, 66, 59,
#        76, 34, 44, 44,  5, 40, 71, 59, 40, 71, 58, 79, 40,  4, 15, 59, 69,
#        15, 34,  5, 35, 69, 69, 32,  8, 17, 23,  5, 58, 76, 71, 59], dtype=int32)

# %% [markdown]
# ## Making training and validation batches
#
# Now I need to split up the data into batches, and into training and validation sets. I should be making a test set here, but I'm not going to worry about that. My test will be if the network can generate new text.
#
# Here I'll make both input and target arrays. The targets are the same as the inputs, except shifted one character over. I'll also drop the last bit of data so that I'll only have completely full batches.
#
# The idea here is to make a 2D matrix where the number of rows is equal to the batch size. Each row will be one long concatenated string from the character data. We'll split this data into a training set and validation set using the `split_frac` keyword. This will keep 90% of the batches in the training set, the other 10% in the validation set.

# %%
def split_data(chars, batch_size, num_steps, split_frac=0.9):
    """ 
    Split character data into training and validation sets, inputs and targets for each set.
    
    Arguments
    ---------
    chars: character array
    batch_size: Size of examples in each of batch
    num_steps: Number of sequence steps to keep in the input and pass to the network
    split_frac: Fraction of batches to keep in the training set
    
    
    Returns train_x, train_y, val_x, val_y
    """
    
    slice_size = batch_size * num_steps
    n_batches = int(len(chars) / slice_size)
    
    # Drop the last few characters to make only full batches
    x = chars[: n_batches*slice_size]
    y = chars[1: n_batches*slice_size + 1]
    
    # Split the data into batch_size slices, then stack them into a 2D matrix 
    x = np.stack(np.split(x, batch_size))
    y = np.stack(np.split(y, batch_size))
    
    # Now x and y are arrays with dimensions batch_size x n_batches*num_steps
    
    # Split into training and validation sets, keep the virst split_frac batches for training
    split_idx = int(n_batches*split_frac)
    train_x, train_y = x[:, :split_idx*num_steps], y[:, :split_idx*num_steps]
    val_x, val_y = x[:, split_idx*num_steps:], y[:, split_idx*num_steps:]
    
    return train_x, train_y, val_x, val_y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
train_x, train_y, val_x, val_y = split_data(chars, 10, 50)

# %%
train_x.shape
# Out:
# (10, 178650)

# %% [markdown]
# Looking at the size of this array, we see that we have rows equal to the batch size. When we want to get a batch out of here, we can grab a subset of this array that contains all the rows but has a width equal to the number of steps in the sequence. The first batch looks like this:

# %%
train_x[:,:50]
# Out:
# array([[20, 76, 34, 44, 58, 17, 23, 40, 13, 69, 69, 69, 55, 34, 44, 44,  5,
#         40,  3, 34, 14, 71, 33, 71, 17, 79, 40, 34, 23, 17, 40, 34, 33, 33,
#         40, 34, 33, 71, 74, 17, 45, 40, 17,  8, 17, 23,  5, 40, 66, 59],
#        [40, 34, 14, 40, 59,  4, 58, 40, 60,  4, 71, 59, 60, 40, 58,  4, 40,
#         79, 58, 34,  5, 82, 64, 40, 34, 59, 79, 15, 17, 23, 17, 48, 40, 63,
#         59, 59, 34, 82, 40, 79, 14, 71, 33, 71, 59, 60, 82, 40, 21, 66],
#        [ 8, 71, 59, 35, 69, 69, 64, 70, 17, 79, 82, 40, 71, 58, 61, 79, 40,
#         79, 17, 58, 58, 33, 17, 48, 35, 40, 25, 76, 17, 40, 44, 23, 71, 24,
#         17, 40, 71, 79, 40, 14, 34, 60, 59, 71,  3, 71, 24, 17, 59, 58],
#        [59, 40, 48, 66, 23, 71, 59, 60, 40, 76, 71, 79, 40, 24,  4, 59,  8,
#         17, 23, 79, 34, 58, 71,  4, 59, 40, 15, 71, 58, 76, 40, 76, 71, 79,
#         69, 21, 23,  4, 58, 76, 17, 23, 40, 15, 34, 79, 40, 58, 76, 71],
#        [40, 71, 58, 40, 71, 79, 82, 40, 79, 71, 23, 65, 64, 40, 79, 34, 71,
#         48, 40, 58, 76, 17, 40,  4, 33, 48, 40, 14, 34, 59, 82, 40, 60, 17,
#         58, 58, 71, 59, 60, 40, 66, 44, 82, 40, 34, 59, 48, 69, 24, 23],
#        [40, 36, 58, 40, 15, 34, 79, 69,  4, 59, 33,  5, 40, 15, 76, 17, 59,
#         40, 58, 76, 17, 40, 79, 34, 14, 17, 40, 17,  8, 17, 59, 71, 59, 60,
#         40, 76, 17, 40, 24, 34, 14, 17, 40, 58,  4, 40, 58, 76, 17, 71],
#        [76, 17, 59, 40, 24,  4, 14, 17, 40,  3,  4, 23, 40, 14, 17, 82, 64,
#         40, 79, 76, 17, 40, 79, 34, 71, 48, 82, 40, 34, 59, 48, 40, 15, 17,
#         59, 58, 40, 21, 34, 24, 74, 40, 71, 59, 58,  4, 40, 58, 76, 17],
#        [45, 40, 21, 66, 58, 40, 59,  4, 15, 40, 79, 76, 17, 40, 15,  4, 66,
#         33, 48, 40, 23, 17, 34, 48, 71, 33,  5, 40, 76, 34,  8, 17, 40, 79,
#         34, 24, 23, 71,  3, 71, 24, 17, 48, 82, 40, 59,  4, 58, 40, 14],
#        [58, 40, 71, 79, 59, 61, 58, 35, 40, 25, 76, 17,  5, 61, 23, 17, 40,
#         44, 23,  4, 44, 23, 71, 17, 58,  4, 23, 79, 40,  4,  3, 40, 34, 40,
#         79,  4, 23, 58, 82, 69, 21, 66, 58, 40, 15, 17, 61, 23, 17, 40],
#        [40, 79, 34, 71, 48, 40, 58,  4, 40, 76, 17, 23, 79, 17, 33,  3, 82,
#         40, 34, 59, 48, 40, 21, 17, 60, 34, 59, 40, 34, 60, 34, 71, 59, 40,
#          3, 23,  4, 14, 40, 58, 76, 17, 40, 21, 17, 60, 71, 59, 59, 71]], dtype=int32)

# %% [markdown]
# I'll write another function to grab batches out of the arrays made by `split_data`. Here each batch will be a sliding window on these arrays with size `batch_size X num_steps`. For example, if we want our network to train on a sequence of 100 characters, `num_steps = 100`. For the next batch, we'll shift this window the next sequence of `num_steps` characters. In this way we can feed batches to the network and the cell states will continue through on each batch.

# %%
def get_batch(arrs, num_steps):
    batch_size, slice_size = arrs[0].shape
    
    n_batches = int(slice_size/num_steps)
    for b in range(n_batches):
        yield [x[:, b*num_steps: (b+1)*num_steps] for x in arrs]

# %% [markdown]
# ## Building the model
#
# Below is a function where I build the graph for the network.

# %%
def build_rnn(num_classes, batch_size=50, num_steps=50, lstm_size=128, num_layers=2,
              learning_rate=0.001, grad_clip=5, sampling=False):
    
    # When we're using this network for sampling later, we'll be passing in
    # one character at a time, so providing an option for that
    if sampling == True:
        batch_size, num_steps = 1, 1

    tf.reset_default_graph()
    
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, [batch_size, num_steps], name='inputs')
    targets = tf.placeholder(tf.int32, [batch_size, num_steps], name='targets')
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    # One-hot encoding the input and target characters
    x_one_hot = tf.one_hot(inputs, num_classes)
    y_one_hot = tf.one_hot(targets, num_classes)

    ### Build the RNN layers
    # Use a basic LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    
    # Add dropout to the cell
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)
    initial_state = cell.zero_state(batch_size, tf.float32)

    ### Run the data through the RNN layers
    # This makes a list where each element is on step in the sequence
    rnn_inputs = [tf.squeeze(i, squeeze_dims=[1]) for i in tf.split(x_one_hot, num_steps, 1)]
    
    # Run each sequence step through the RNN and collect the outputs
    outputs, state = tf.contrib.rnn.static_rnn(cell, rnn_inputs, initial_state=initial_state)
    final_state = state
    
    # Reshape output so it's a bunch of rows, one output row for each step for each batch
    seq_output = tf.concat(outputs, axis=1)
    output = tf.reshape(seq_output, [-1, lstm_size])
    
    # Now connect the RNN putputs to a softmax layer
    with tf.variable_scope('softmax'):
        softmax_w = tf.Variable(tf.truncated_normal((lstm_size, num_classes), stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(num_classes))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and batch
    logits = tf.matmul(output, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    preds = tf.nn.softmax(logits, name='predictions')
    
    # Reshape the targets to match the logits
    y_reshaped = tf.reshape(y_one_hot, [-1, num_classes])
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped)
    cost = tf.reduce_mean(loss)

    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(cost, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    # Export the nodes
    # NOTE: I'm using a namedtuple here because I think they are cool
    export_nodes = ['inputs', 'targets', 'initial_state', 'final_state',
                    'keep_prob', 'cost', 'preds', 'optimizer']
    Graph = namedtuple('Graph', export_nodes)
    local_dict = locals()
    graph = Graph(*[local_dict[each] for each in export_nodes])
    
    return graph

# %% [markdown]
# ## Hyperparameters
#
# Here I'm defining the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to write it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that heps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 100
num_steps = 100 
lstm_size = 512
num_layers = 2
learning_rate = 0.001
keep_prob = 0.5

# %% [markdown]
# ## Training
#
# Time for training which is pretty straightforward. Here I pass in some data, and get an LSTM state back. Then I pass that state back in to the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I calculate the validation loss and save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}_v{validation loss}.ckpt`

# %%
epochs = 20
# Save every N iterations
save_every_n = 200
train_x, train_y, val_x, val_y = split_data(chars, batch_size, num_steps)

model = build_rnn(len(vocab), 
                  batch_size=batch_size,
                  num_steps=num_steps,
                  learning_rate=learning_rate,
                  lstm_size=lstm_size,
                  num_layers=num_layers)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    
    n_batches = int(train_x.shape[1]/num_steps)
    iterations = n_batches * epochs
    for e in range(epochs):
        
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for b, (x, y) in enumerate(get_batch([train_x, train_y], num_steps), 1):
            iteration = e*n_batches + b
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.cost, model.final_state, model.optimizer], 
                                                 feed_dict=feed)
            loss += batch_loss
            end = time.time()
            print('Epoch {}/{} '.format(e+1, epochs),
                  'Iteration {}/{}'.format(iteration, iterations),
                  'Training loss: {:.4f}'.format(loss/b),
                  '{:.4f} sec/batch'.format((end-start)))
        
            
            if (iteration%save_every_n == 0) or (iteration == iterations):
                # Check performance, notice dropout has been set to 1
                val_loss = []
                new_state = sess.run(model.initial_state)
                for x, y in get_batch([val_x, val_y], num_steps):
                    feed = {model.inputs: x,
                            model.targets: y,
                            model.keep_prob: 1.,
                            model.initial_state: new_state}
                    batch_loss, new_state = sess.run([model.cost, model.final_state], feed_dict=feed)
                    val_loss.append(batch_loss)

                print('Validation loss:', np.mean(val_loss),
                      'Saving checkpoint!')
                saver.save(sess, "checkpoints/i{}_l{}_v{:.3f}.ckpt".format(iteration, lstm_size, np.mean(val_loss)))
# Out:
# Epoch 1/20  Iteration 1/3560 Training loss: 4.4209 2.7739 sec/batch
# Epoch 1/20  Iteration 2/3560 Training loss: 4.3819 1.2019 sec/batch
# Epoch 1/20  Iteration 3/3560 Training loss: 4.2308 1.2042 sec/batch
# Epoch 1/20  Iteration 4/3560 Training loss: 4.3785 1.2037 sec/batch
# Epoch 1/20  Iteration 5/3560 Training loss: 4.3374 1.2029 sec/batch
# Epoch 1/20  Iteration 6/3560 Training loss: 4.2567 1.2032 sec/batch
# Epoch 1/20  Iteration 7/3560 Training loss: 4.1712 1.2023 sec/batch
# Epoch 1/20  Iteration 8/3560 Training loss: 4.0941 1.2026 sec/batch
# Epoch 1/20  Iteration 9/3560 Training loss: 4.0272 1.2007 sec/batch
# Epoch 1/20  Iteration 10/3560 Training loss: 3.9729 1.2052 sec/batch
# Epoch 1/20  Iteration 11/3560 Training loss: 3.9228 1.2026 sec/batch
# Epoch 1/20  Iteration 12/3560 Training loss: 3.8802 1.1910 sec/batch
# Epoch 1/20  Iteration 13/3560 Training loss: 3.8424 1.2029 sec/batch
# Epoch 1/20  Iteration 14/3560 Training loss: 3.8089 1.2037 sec/batch
# Epoch 1/20  Iteration 15/3560 Training loss: 3.7789 1.2041 sec/batch
# Epoch 1/20  Iteration 16/3560 Training loss: 3.7503 1.2046 sec/batch
# Epoch 1/20  Iteration 17/3560 Training loss: 3.7240 1.2023 sec/batch
# Epoch 1/20  Iteration 18/3560 Training loss: 3.7019 1.2033 sec/batch
# Epoch 1/20  Iteration 19/3560 Training loss: 3.6810 1.2041 sec/batch
# Epoch 1/20  Iteration 20/3560 Training loss: 3.6601 1.2026 sec/batch
# Epoch 1/20  Iteration 21/3560 Training loss: 3.6419 1.2119 sec/batch
# Epoch 1/20  Iteration 22/3560 Training loss: 3.6248 1.2111 sec/batch
# Epoch 1/20  Iteration 23/3560 Training loss: 3.6086 1.2021 sec/batch
# Epoch 1/20  Iteration 24/3560 Training loss: 3.5938 1.2055 sec/batch
# Epoch 1/20  Iteration 25/3560 Training loss: 3.5794 1.2017 sec/batch
# Epoch 1/20  Iteration 26/3560 Training loss: 3.5663 1.2115 sec/batch
# Epoch 1/20  Iteration 27/3560 Training loss: 3.5545 1.2047 sec/batch
# Epoch 1/20  Iteration 28/3560 Training loss: 3.5425 1.2064 sec/batch
# Epoch 1/20  Iteration 29/3560 Training loss: 3.5314 1.2040 sec/batch
# Epoch 1/20  Iteration 30/3560 Training loss: 3.5213 1.1983 sec/batch
# Epoch 1/20  Iteration 31/3560 Training loss: 3.5124 1.2026 sec/batch
# Epoch 1/20  Iteration 32/3560 Training loss: 3.5031 1.2026 sec/batch
# Epoch 1/20  Iteration 33/3560 Training loss: 3.4938 1.2116 sec/batch
# Epoch 4/20  Iteration 682/3560 Training loss: 1.8471 1.2049 sec/batch
# Epoch 4/20  Iteration 683/3560 Training loss: 1.8467 1.2040 sec/batch
# Epoch 4/20  Iteration 684/3560 Training loss: 1.8463 1.2032 sec/batch
# Epoch 4/20  Iteration 685/3560 Training loss: 1.8457 1.2051 sec/batch
# ...
# Epoch 19/20  Iteration 3340/3560 Training loss: 1.1957 1.2127 sec/batch
# Epoch 19/20  Iteration 3341/3560 Training loss: 1.1958 1.2065 sec/batch
# Epoch 19/20  Iteration 3342/3560 Training loss: 1.1959 1.2049 sec/batch
# Epoch 19/20  Iteration 3343/3560 Training loss: 1.1959 1.2035 sec/batch
# Epoch 19/20  Iteration 3344/3560 Training loss: 1.1959 1.2027 sec/batch
# Epoch 19/20  Iteration 3345/3560 Training loss: 1.1962 1.2043 sec/batch
# Epoch 19/20  Iteration 3346/3560 Training loss: 1.1963 1.2043 sec/batch
# Epoch 19/20  Iteration 3347/3560 Training loss: 1.1962 1.2024 sec/batch
# Epoch 19/20  Iteration 3348/3560 Training loss: 1.1965 1.1888 sec/batch
# Epoch 19/20  Iteration 3349/3560 Training loss: 1.1964 1.2113 sec/batch
# Epoch 19/20  Iteration 3350/3560 Training loss: 1.1966 1.2032 sec/batch
# Epoch 19/20  Iteration 3351/3560 Training loss: 1.1966 1.2016 sec/batch
# Epoch 19/20  Iteration 3352/3560 Training loss: 1.1968 1.2031 sec/batch
# Epoch 19/20  Iteration 3353/3560 Training loss: 1.1970 1.2039 sec/batch
# Epoch 19/20  Iteration 3354/3560 Training loss: 1.1969 1.2032 sec/batch
# Epoch 19/20  Iteration 3355/3560 Training loss: 1.1967 1.2034 sec/batch
# Epoch 19/20  Iteration 3356/3560 Training loss: 1.1966 1.2025 sec/batch
# Epoch 19/20  Iteration 3357/3560 Training loss: 1.1967 1.2028 sec/batch
# Epoch 19/20  Iteration 3358/3560 Training loss: 1.1966 1.2033 sec/batch
# Epoch 19/20  Iteration 3359/3560 Training loss: 1.1965 1.2048 sec/batch
# Epoch 19/20  Iteration 3360/3560 Training loss: 1.1966 1.2044 sec/batch
# Epoch 19/20  Iteration 3361/3560 Training loss: 1.1966 1.2032 sec/batch
# Epoch 19/20  Iteration 3362/3560 Training loss: 1.1965 1.2039 sec/batch
# Epoch 19/20  Iteration 3363/3560 Training loss: 1.1963 1.2031 sec/batch
# Epoch 19/20  Iteration 3364/3560 Training loss: 1.1964 1.2099 sec/batch
# Epoch 19/20  Iteration 3365/3560 Training loss: 1.1965 1.2064 sec/batch
# Epoch 19/20  Iteration 3366/3560 Training loss: 1.1965 1.2033 sec/batch
# Epoch 19/20  Iteration 3367/3560 Training loss: 1.1965 1.2028 sec/batch
# Epoch 19/20  Iteration 3368/3560 Training loss: 1.1965 1.2029 sec/batch
# Epoch 19/20  Iteration 3369/3560 Training loss: 1.1966 1.2024 sec/batch
# Epoch 19/20  Iteration 3370/3560 Training loss: 1.1965 1.2035 sec/batch
# Epoch 19/20  Iteration 3371/3560 Training loss: 1.1967 1.2076 sec/batch
# Epoch 19/20  Iteration 3372/3560 Training loss: 1.1971 1.2032 sec/batch
# Epoch 19/20  Iteration 3373/3560 Training loss: 1.1972 1.2042 sec/batch
# Epoch 19/20  Iteration 3374/3560 Training loss: 1.1972 1.2026 sec/batch
# Epoch 19/20  Iteration 3375/3560 Training loss: 1.1972 1.2061 sec/batch
# Epoch 19/20  Iteration 3376/3560 Training loss: 1.1972 1.2023 sec/batch
# Epoch 19/20  Iteration 3377/3560 Training loss: 1.1974 1.2047 sec/batch
# Epoch 19/20  Iteration 3378/3560 Training loss: 1.1974 1.2039 sec/batch
# Epoch 19/20  Iteration 3379/3560 Training loss: 1.1975 1.2032 sec/batch
# Epoch 19/20  Iteration 3380/3560 Training loss: 1.1974 1.1953 sec/batch
# Epoch 19/20  Iteration 3381/3560 Training loss: 1.1973 1.2034 sec/batch
# Epoch 19/20  Iteration 3382/3560 Training loss: 1.1975 1.2015 sec/batch
# Epoch 20/20  Iteration 3383/3560 Training loss: 1.3117 1.2048 sec/batch
# Epoch 20/20  Iteration 3384/3560 Training loss: 1.2715 1.2051 sec/batch
# Epoch 20/20  Iteration 3385/3560 Training loss: 1.2475 1.2035 sec/batch
# Epoch 20/20  Iteration 3386/3560 Training loss: 1.2411 1.2051 sec/batch
# Epoch 20/20  Iteration 3387/3560 Training loss: 1.2280 1.2023 sec/batch
# Epoch 20/20  Iteration 3388/3560 Training loss: 1.2163 1.2039 sec/batch
# Epoch 20/20  Iteration 3389/3560 Training loss: 1.2144 1.2058 sec/batch
# Epoch 20/20  Iteration 3390/3560 Training loss: 1.2125 1.2046 sec/batch
# Epoch 20/20  Iteration 3391/3560 Training loss: 1.2115 1.1900 sec/batch
# Epoch 20/20  Iteration 3392/3560 Training loss: 1.2106 1.2022 sec/batch
# Epoch 20/20  Iteration 3393/3560 Training loss: 1.2072 1.2038 sec/batch
# Epoch 20/20  Iteration 3394/3560 Training loss: 1.2056 1.2037 sec/batch
# Epoch 20/20  Iteration 3395/3560 Training loss: 1.2055 1.2026 sec/batch
# Epoch 20/20  Iteration 3396/3560 Training loss: 1.2062 1.2055 sec/batch
# Epoch 20/20  Iteration 3397/3560 Training loss: 1.2048 1.2032 sec/batch
# Epoch 20/20  Iteration 3398/3560 Training loss: 1.2026 1.2054 sec/batch
# Epoch 20/20  Iteration 3399/3560 Training loss: 1.2027 1.2045 sec/batch
# Epoch 20/20  Iteration 3400/3560 Training loss: 1.2035 1.2063 sec/batch
# Validation loss: 1.12943 Saving checkpoint!
# Epoch 20/20  Iteration 3401/3560 Training loss: 1.2120 1.2057 sec/batch
# Epoch 20/20  Iteration 3402/3560 Training loss: 1.2125 1.2026 sec/batch
# Epoch 20/20  Iteration 3403/3560 Training loss: 1.2114 1.2048 sec/batch
# Epoch 20/20  Iteration 3404/3560 Training loss: 1.2111 1.2031 sec/batch
# Epoch 20/20  Iteration 3405/3560 Training loss: 1.2101 1.2025 sec/batch
# Epoch 20/20  Iteration 3406/3560 Training loss: 1.2099 1.2034 sec/batch
# Epoch 20/20  Iteration 3407/3560 Training loss: 1.2096 1.2030 sec/batch
# Epoch 20/20  Iteration 3408/3560 Training loss: 1.2078 1.1907 sec/batch
# Epoch 20/20  Iteration 3409/3560 Training loss: 1.2064 1.2036 sec/batch
# Epoch 20/20  Iteration 3410/3560 Training loss: 1.2066 1.2044 sec/batch
# Epoch 20/20  Iteration 3411/3560 Training loss: 1.2061 1.2028 sec/batch
# Epoch 20/20  Iteration 3412/3560 Training loss: 1.2062 1.2030 sec/batch
# Epoch 20/20  Iteration 3413/3560 Training loss: 1.2053 1.2027 sec/batch
# Epoch 20/20  Iteration 3414/3560 Training loss: 1.2043 1.2033 sec/batch
# Epoch 20/20  Iteration 3415/3560 Training loss: 1.2044 1.2069 sec/batch
# Epoch 20/20  Iteration 3416/3560 Training loss: 1.2042 1.1954 sec/batch
# Epoch 20/20  Iteration 3417/3560 Training loss: 1.2034 1.2100 sec/batch
# Epoch 20/20  Iteration 3418/3560 Training loss: 1.2029 1.1979 sec/batch
# Epoch 20/20  Iteration 3419/3560 Training loss: 1.2019 1.2004 sec/batch
# Epoch 20/20  Iteration 3420/3560 Training loss: 1.2006 1.2036 sec/batch
# Epoch 20/20  Iteration 3421/3560 Training loss: 1.1993 1.2019 sec/batch
# Epoch 20/20  Iteration 3422/3560 Training loss: 1.1990 1.2050 sec/batch
# Epoch 20/20  Iteration 3423/3560 Training loss: 1.1983 1.2030 sec/batch
# Epoch 20/20  Iteration 3424/3560 Training loss: 1.1990 1.2044 sec/batch
# Epoch 20/20  Iteration 3425/3560 Training loss: 1.1987 1.2025 sec/batch
# Epoch 20/20  Iteration 3426/3560 Training loss: 1.1980 1.2103 sec/batch
# Epoch 20/20  Iteration 3427/3560 Training loss: 1.1979 1.1954 sec/batch
# Epoch 20/20  Iteration 3428/3560 Training loss: 1.1973 1.2040 sec/batch
# Epoch 20/20  Iteration 3429/3560 Training loss: 1.1968 1.2123 sec/batch
# Epoch 20/20  Iteration 3430/3560 Training loss: 1.1964 1.2040 sec/batch
# Epoch 20/20  Iteration 3431/3560 Training loss: 1.1962 1.2046 sec/batch
# Epoch 20/20  Iteration 3432/3560 Training loss: 1.1962 1.2028 sec/batch
# Epoch 20/20  Iteration 3433/3560 Training loss: 1.1955 1.2040 sec/batch
# Epoch 20/20  Iteration 3434/3560 Training loss: 1.1961 1.1998 sec/batch
# Epoch 20/20  Iteration 3435/3560 Training loss: 1.1961 1.2126 sec/batch
# Epoch 20/20  Iteration 3436/3560 Training loss: 1.1961 1.2057 sec/batch
# Epoch 20/20  Iteration 3437/3560 Training loss: 1.1957 1.2048 sec/batch
# Epoch 20/20  Iteration 3438/3560 Training loss: 1.1957 1.1965 sec/batch
# Epoch 20/20  Iteration 3439/3560 Training loss: 1.1959 1.2098 sec/batch
# Epoch 20/20  Iteration 3440/3560 Training loss: 1.1956 1.2056 sec/batch
# Epoch 20/20  Iteration 3441/3560 Training loss: 1.1952 1.2036 sec/batch
# Epoch 20/20  Iteration 3442/3560 Training loss: 1.1957 1.2114 sec/batch
# Epoch 20/20  Iteration 3443/3560 Training loss: 1.1957 1.2028 sec/batch
# Epoch 20/20  Iteration 3444/3560 Training loss: 1.1962 1.2028 sec/batch
# Epoch 20/20  Iteration 3445/3560 Training loss: 1.1964 1.2036 sec/batch
# Epoch 20/20  Iteration 3446/3560 Training loss: 1.1965 1.2033 sec/batch
# Epoch 20/20  Iteration 3447/3560 Training loss: 1.1965 1.2034 sec/batch
# Epoch 20/20  Iteration 3448/3560 Training loss: 1.1967 1.2039 sec/batch
# Epoch 20/20  Iteration 3449/3560 Training loss: 1.1969 1.2029 sec/batch
# Epoch 20/20  Iteration 3450/3560 Training loss: 1.1966 1.2035 sec/batch
# Epoch 20/20  Iteration 3451/3560 Training loss: 1.1966 1.2026 sec/batch
# Epoch 20/20  Iteration 3452/3560 Training loss: 1.1966 1.2043 sec/batch
# Epoch 20/20  Iteration 3453/3560 Training loss: 1.1970 1.2033 sec/batch
# Epoch 20/20  Iteration 3454/3560 Training loss: 1.1972 1.2055 sec/batch
# Epoch 20/20  Iteration 3455/3560 Training loss: 1.1976 1.2101 sec/batch
# Epoch 20/20  Iteration 3456/3560 Training loss: 1.1973 1.2015 sec/batch
# Epoch 20/20  Iteration 3457/3560 Training loss: 1.1972 1.2114 sec/batch
# Epoch 20/20  Iteration 3458/3560 Training loss: 1.1972 1.2040 sec/batch
# Epoch 20/20  Iteration 3459/3560 Training loss: 1.1970 1.2027 sec/batch
# Epoch 20/20  Iteration 3460/3560 Training loss: 1.1970 1.2119 sec/batch
# Epoch 20/20  Iteration 3461/3560 Training loss: 1.1963 1.2044 sec/batch
# Epoch 20/20  Iteration 3462/3560 Training loss: 1.1962 1.2029 sec/batch
# Epoch 20/20  Iteration 3463/3560 Training loss: 1.1957 1.2046 sec/batch
# Epoch 20/20  Iteration 3464/3560 Training loss: 1.1957 1.2061 sec/batch
# Epoch 20/20  Iteration 3465/3560 Training loss: 1.1952 1.2062 sec/batch
# Epoch 20/20  Iteration 3466/3560 Training loss: 1.1951 1.2041 sec/batch
# Epoch 20/20  Iteration 3467/3560 Training loss: 1.1948 1.2115 sec/batch
# Epoch 20/20  Iteration 3468/3560 Training loss: 1.1947 1.2051 sec/batch
# Epoch 20/20  Iteration 3469/3560 Training loss: 1.1945 1.2036 sec/batch
# Epoch 20/20  Iteration 3470/3560 Training loss: 1.1944 1.2122 sec/batch
# Epoch 20/20  Iteration 3471/3560 Training loss: 1.1940 1.2042 sec/batch
# Epoch 20/20  Iteration 3472/3560 Training loss: 1.1940 1.2034 sec/batch
# Epoch 20/20  Iteration 3473/3560 Training loss: 1.1937 1.2056 sec/batch
# Epoch 20/20  Iteration 3474/3560 Training loss: 1.1936 1.2017 sec/batch
# Epoch 20/20  Iteration 3475/3560 Training loss: 1.1933 1.2049 sec/batch
# Epoch 20/20  Iteration 3476/3560 Training loss: 1.1929 1.2037 sec/batch
# Epoch 20/20  Iteration 3477/3560 Training loss: 1.1926 1.2028 sec/batch
# Epoch 20/20  Iteration 3478/3560 Training loss: 1.1926 1.2028 sec/batch
# Epoch 20/20  Iteration 3479/3560 Training loss: 1.1925 1.2040 sec/batch
# Epoch 20/20  Iteration 3480/3560 Training loss: 1.1921 1.2038 sec/batch
# Epoch 20/20  Iteration 3481/3560 Training loss: 1.1918 1.2037 sec/batch
# Epoch 20/20  Iteration 3482/3560 Training loss: 1.1916 1.2040 sec/batch
# Epoch 20/20  Iteration 3483/3560 Training loss: 1.1914 1.2051 sec/batch
# Epoch 20/20  Iteration 3484/3560 Training loss: 1.1912 1.2048 sec/batch
# Epoch 20/20  Iteration 3485/3560 Training loss: 1.1911 1.2021 sec/batch
# Epoch 20/20  Iteration 3486/3560 Training loss: 1.1910 1.2025 sec/batch
# Epoch 20/20  Iteration 3487/3560 Training loss: 1.1908 1.2034 sec/batch
# Epoch 20/20  Iteration 3488/3560 Training loss: 1.1907 1.2118 sec/batch
# Epoch 20/20  Iteration 3489/3560 Training loss: 1.1906 1.2116 sec/batch
# Epoch 20/20  Iteration 3490/3560 Training loss: 1.1906 1.2037 sec/batch
# Epoch 20/20  Iteration 3491/3560 Training loss: 1.1904 1.2050 sec/batch
# Epoch 20/20  Iteration 3492/3560 Training loss: 1.1904 1.2027 sec/batch
# Epoch 20/20  Iteration 3493/3560 Training loss: 1.1903 1.2045 sec/batch
# Epoch 20/20  Iteration 3494/3560 Training loss: 1.1902 1.2039 sec/batch
# Epoch 20/20  Iteration 3495/3560 Training loss: 1.1901 1.2094 sec/batch
# Epoch 20/20  Iteration 3496/3560 Training loss: 1.1899 1.2115 sec/batch
# Epoch 20/20  Iteration 3497/3560 Training loss: 1.1896 1.2067 sec/batch
# Epoch 20/20  Iteration 3498/3560 Training loss: 1.1893 1.2028 sec/batch
# Epoch 20/20  Iteration 3499/3560 Training loss: 1.1893 1.2113 sec/batch
# Epoch 20/20  Iteration 3500/3560 Training loss: 1.1893 1.2028 sec/batch
# Epoch 20/20  Iteration 3501/3560 Training loss: 1.1892 1.2033 sec/batch
# Epoch 20/20  Iteration 3502/3560 Training loss: 1.1892 1.2046 sec/batch
# Epoch 20/20  Iteration 3503/3560 Training loss: 1.1891 1.2032 sec/batch
# Epoch 20/20  Iteration 3504/3560 Training loss: 1.1888 1.2047 sec/batch
# Epoch 20/20  Iteration 3505/3560 Training loss: 1.1885 1.2035 sec/batch
# Epoch 20/20  Iteration 3506/3560 Training loss: 1.1884 1.2039 sec/batch
# Epoch 20/20  Iteration 3507/3560 Training loss: 1.1883 1.1925 sec/batch
# Epoch 20/20  Iteration 3508/3560 Training loss: 1.1879 1.2044 sec/batch
# Epoch 20/20  Iteration 3509/3560 Training loss: 1.1879 1.2045 sec/batch
# Epoch 20/20  Iteration 3510/3560 Training loss: 1.1878 1.2043 sec/batch
# Epoch 20/20  Iteration 3547/3560 Training loss: 1.1875 1.2016 sec/batch
# Epoch 20/20  Iteration 3548/3560 Training loss: 1.1875 1.2044 sec/batch
# Epoch 20/20  Iteration 3549/3560 Training loss: 1.1876 1.2034 sec/batch
# Epoch 20/20  Iteration 3550/3560 Training loss: 1.1880 1.2039 sec/batch
# Epoch 20/20  Iteration 3551/3560 Training loss: 1.1881 1.2011 sec/batch
# Epoch 20/20  Iteration 3552/3560 Training loss: 1.1881 1.2039 sec/batch
# Epoch 20/20  Iteration 3553/3560 Training loss: 1.1881 1.2032 sec/batch
# Epoch 20/20  Iteration 3554/3560 Training loss: 1.1880 1.2117 sec/batch
# Epoch 20/20  Iteration 3555/3560 Training loss: 1.1881 1.2060 sec/batch
# Epoch 20/20  Iteration 3556/3560 Training loss: 1.1881 1.2032 sec/batch
# Epoch 20/20  Iteration 3557/3560 Training loss: 1.1882 1.2040 sec/batch
# Epoch 20/20  Iteration 3558/3560 Training loss: 1.1880 1.1979 sec/batch
# Epoch 20/20  Iteration 3559/3560 Training loss: 1.1879 1.2037 sec/batch
# Epoch 20/20  Iteration 3560/3560 Training loss: 1.1880 1.2026 sec/batch
# Validation loss: 1.12195 Saving checkpoint!

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints/i3560_l512_v1.122.ckpt"
# all_model_checkpoint_paths: "checkpoints/i200_l512_v2.436.ckpt"
# all_model_checkpoint_paths: "checkpoints/i400_l512_v1.984.ckpt"
# all_model_checkpoint_paths: "checkpoints/i600_l512_v1.754.ckpt"
# all_model_checkpoint_paths: "checkpoints/i800_l512_v1.598.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1000_l512_v1.479.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1200_l512_v1.396.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1400_l512_v1.322.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1600_l512_v1.282.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1800_l512_v1.245.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2000_l512_v1.219.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2200_l512_v1.198.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2400_l512_v1.187.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2600_l512_v1.168.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2800_l512_v1.158.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3000_l512_v1.145.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3200_l512_v1.136.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3400_l512_v1.129.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3560_l512_v1.122.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = build_rnn(vocab_size, lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.preds, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.preds, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
checkpoint = "checkpoints/i3560_l512_v1.122.ckpt"
sampled_text = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(sampled_text)
# Out:
# Farnish, and
# to boded anything that she were not so interesting far to be
# position, were that the conversation to the storm of silves, and with a liver
# in the same sister--that is to see an and some other, and the same she
# would say if he can too hear."
#
# "Yish in the stood with moments, and I would not say anything with the
# senteral post of a peasant of a province and making my fact to him that
# you've all those particular position to me?".
#
# "Well, why, I say that.. He didn't know," he was clearing, and should
# still be took him with the country.
#
# "That I was anything at the men of the chering, and who has a glas of
# candles the marshal were so supprehensed," said the old moment. "I'd an and
# shame, I have been satisfied," said Anna, looking at another whole were
# all the contrary, who was a subject, they were starting a strange time
# off the station. To three the sisters he did not know him. He felt all the
# sound it is seemed of the timidicy, what he was as he had no secrets of
# a bed and hout of the thind and the convictions of his sill, and seemed
# to her to the country, and then the door.
#
# Those who had been done and settled anything, the child was not a composure
# of his stifly at the country.
#
# "The coachman had been the seet of their man, but which is a chuscilory.
# A preparation to most pleasurt of me, but I have not cheesed."
#
# "You could not believe it of you and with my carriage," said Anna.
# "You know what you don't know what you can?" said Alexey
# Alexandrovitch. "What a side--it's simply a disturbant story.
#
# I can be there and me, a sight in this sorts."
#
# "You know, the children will go to a bride's course," said Stepan
# Arkadyevitch; "would have took anything to him? And how did you know, that
# the paper, which it's net and more a peasant frost and mentioned that she do you
# stall my bride?" he said, which in sight of his wife and home if the
# peasant said, she did not concent to stiff any strange, and the
# same as a will withed the chief and at a persistent.
#
# He was not le
