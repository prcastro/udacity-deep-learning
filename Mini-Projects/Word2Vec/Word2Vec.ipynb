# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
t = 1e-5
counts = Counter(int_words)
total = len(int_words)

# %%
freqs = {word: count/total for word, count in counts.items()}
p_drop = {word: 1 - np.sqrt(t/freqs[word]) for word in counts}
train_words = [word for word in int_words if p_drop[word] < np.random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    c = np.random.choice(range(1, window_size + 1))
    start_idx = max(idx-c, 0)
    end_idx = min(idx+c, len(words) - 1)
    idxs = range(start_idx, end_idx + 1)
    return [words[i] for i in idxs if i != idx]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6310 0.2385 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5558 0.2333 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4632 0.2285 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5705 0.2208 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4600 0.2256 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5047 0.2278 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5047 0.2243 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4724 0.2220 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4078 0.2216 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3773 0.2206 sec/batch
# Nearest to years: serendip, constrain, ren, ext, gua, din, compares, sdk,
# Nearest to its: multiplying, katydid, compresses, bihar, tempest, dowleh, flavoured, europe,
# Nearest to about: colossians, resigning, elis, trolleys, autopsy, membranes, malignancies, anastasio,
# Nearest to one: bough, allowance, latinos, oligarchy, abandon, advancing, dimers, impede,
# Nearest to was: including, giraud, peltier, readers, mammal, manmade, headdress, appraisals,
# Nearest to an: posed, achieved, cheeses, entrepreneurial, database, ingres, mandate, curtiz,
# Nearest to is: designing, fortress, hejira, warship, seal, lash, rushen, actinopterygii,
# Nearest to only: eil, yorkers, singers, mtr, faithful, ghostbusters, robert, steinitz,
# Nearest to joseph: exceptionally, ups, heat, guayas, uncanny, dealbata, caudillo, circulate,
# Nearest to professional: kwanzaa, pelagius, alves, ti, botswana, therapeutae, weighing, roo,
# Nearest to file: fruitarians, forging, istria, bounced, hitman, seoul, mordechai, maoist,
# Nearest to universe: five, geddes, edifices, kaiser, indeed, medved, cantonese, ruined,
# Nearest to nobel: blg, subsidized, scrat, elaborate, bootlegged, universals, kidnapped, tano,
# Nearest to operations: mascarenhas, medulla, avogadro, quickened, retracted, bra, hexane, hunter,
# Nearest to primarily: graze, sarcastically, maltose, prozac, strabismus, travels, home, withholding,
# Nearest to square: ricks, clamp, arbitrary, sibilant, deviations, cutscenes, stepwise, extinct,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4711 0.2231 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3800 0.2223 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3309 0.2342 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2449 0.2253 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2112 0.2239 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1653 0.2269 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1085 0.2282 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1107 0.2700 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0293 0.2453 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0380 0.2196 sec/batch
# Nearest to years: compares, tangent, constrain, din, ren, serendip, observe, pin,
# Nearest to its: europe, multiplying, word, compresses, bihar, multilingual, adjustment, poincar,
# Nearest to about: colossians, went, autopsy, membranes, elis, maintaining, pitched, led,
# Nearest to one: abandon, bough, philosophical, allowance, latinos, mathematics, rust, oligarchy,
# Nearest to was: including, readers, secure, giraud, coast, valuation, mammal, drought,
# Nearest to an: database, achieved, posed, dimensions, mandate, cheeses, unusual, entrepreneurial,
# Nearest to is: designing, somewhat, consumption, crowds, preference, seal, process, replaced,
# Nearest to only: yorkers, singers, robert, recipients, eil, hour, steinitz, faithful,
# Nearest to joseph: exceptionally, ups, heat, guayas, yet, circulate, uncanny, raleigh,
# Nearest to professional: kwanzaa, ti, weighing, alves, belonged, ain, botswana, therapeutae,
# Nearest to file: forging, fruitarians, istria, mortensen, mishneh, mordechai, bounced, reliable,
# Nearest to universe: indeed, five, applying, portion, geddes, edifices, kaiser, populated,
# Nearest to nobel: blg, subsidized, whirl, universals, kidnapped, elaborate, hearted, scrat,
# Nearest to operations: mascarenhas, hunter, may, retracted, turns, quickened, medulla, eurocard,
# Nearest to primarily: fast, home, l, prozac, graze, donatien, sarcastically, enlightened,
# Nearest to square: arbitrary, deviations, ricks, clamp, cemetery, fluctuations, who, cutscenes,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9495 0.2396 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9161 0.2295 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9184 0.2548 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8521 0.2463 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8618 0.2498 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8378 0.2464 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8247 0.2415 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7969 0.2430 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8146 0.2431 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7726 0.2429 sec/batch
# Nearest to years: constrain, ren, compares, tangent, serendip, outweighs, din, charm,
# Nearest to its: multiplying, europe, compresses, multilingual, poincar, bihar, katydid, mythological,
# Nearest to about: colossians, resigning, pitched, membranes, autopsy, went, elis, maintaining,
# Nearest to one: four, latinos, bough, born, gustave, gt, allowance, scarce,
# Nearest to was: including, secure, readers, coast, flooding, australia, valuation, tall,
# Nearest to an: achieved, database, norwegian, dimensions, mandate, posed, cheeses, unusual,
# Nearest to is: crowds, consumption, designing, preference, somewhat, denoted, entails, revisionist,
# Nearest to only: yorkers, faithful, singers, robert, mtr, eil, steinitz, hour,
# Nearest to joseph: ups, exceptionally, uncanny, heat, circulate, guayas, dealbata, raleigh,
# Nearest to professional: kwanzaa, ti, weighing, belonged, ain, continuously, alves, therapeutae,
# Nearest to file: forging, reliable, fruitarians, mortensen, istria, pilgrimage, mishneh, muon,
# Nearest to universe: indeed, geddes, kaiser, edifices, applying, portion, medved, shifting,
# Nearest to nobel: blg, recipient, statesman, subsidized, hearted, kidnapped, universals, whirl,
# Nearest to operations: mascarenhas, retracted, eurocard, turns, hunter, colspan, quickened, may,
# Nearest to primarily: fast, travels, l, prozac, graze, index, sarcastically, home,
# Nearest to square: arbitrary, deviations, cemetery, fluctuations, ricks, clamp, extinct, lasting,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7893 0.2439 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7618 0.2419 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7191 0.2519 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7254 0.2499 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7505 0.2451 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7148 0.2428 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7062 0.2429 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7287 0.2400 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7193 0.2509 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6638 0.2463 sec/batch
# Nearest to years: constrain, ren, tangent, compares, outweighs, serendip, fuchs, charm,
# Nearest to its: multiplying, europe, katydid, bihar, compresses, gyula, poincar, lays,
# Nearest to about: colossians, resigning, pitched, elis, cavett, autopsy, malignancies, went,
# Nearest to one: four, born, eight, gustave, latinos, bough, gt, five,
# Nearest to was: including, coast, secure, australia, abstained, grammatically, contractually, colleague,
# Nearest to an: database, mandate, dimensions, cheeses, achieved, norwegian, posed, satisfying,
# Nearest to is: crowds, designing, somewhat, consumption, preference, we, revisionist, actinopterygii,
# Nearest to only: yorkers, mtr, faithful, eil, steinitz, singers, foil, recipients,
# Nearest to joseph: ups, uncanny, exceptionally, dealbata, raleigh, hammerstein, ancien, cfaf,
# Nearest to professional: kwanzaa, ti, weighing, alves, botswana, belonged, therapeutae, addams,
# Nearest to file: forging, fruitarians, reliable, mishneh, seoul, cataract, muon, istria,
# Nearest to universe: indeed, edifices, geddes, lussac, occurrence, medved, confident, applying,
# Nearest to nobel: statesman, recipient, blg, universals, indochina, kidnapped, subsidized, hearted,
# Nearest to operations: mascarenhas, quickened, retracted, eurocard, avogadro, colspan, medulla, turns,
# Nearest to primarily: fast, graze, iq, prozac, travels, sarcastically, index, meme,
# Nearest to square: arbitrary, deviations, cemetery, clamp, ricks, pozna, liberia, extinct,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6784 0.2463 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6656 0.2410 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6293 0.2502 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6156 0.2455 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6216 0.2440 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6378 0.2425 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6188 0.1761 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5600 0.2438 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5219 0.2424 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4859 0.2515 sec/batch
# Nearest to years: constrain, outweighs, serendip, compares, tangent, ren, charm, fountain,
# Nearest to its: multiplying, katydid, europe, compresses, bihar, lepidoptera, poincar, lays,
# Nearest to about: resigning, colossians, pitched, elis, malignancies, zambia, autopsy, bicoid,
# Nearest to one: four, eight, born, five, russian, gustave, york, cricketer,
# Nearest to was: including, abstained, secure, coast, november, australia, peacecraft, dead,
# Nearest to an: cheeses, database, mandate, dimensions, achieved, posed, unusual, satisfying,
# Nearest to is: somewhat, consumption, denoted, we, actinopterygii, designing, revisionist, crowds,
# Nearest to only: yorkers, mtr, eil, faithful, steinitz, recipients, subtext, singers,
# Nearest to joseph: ups, uncanny, naturalist, dealbata, hammerstein, ancien, exceptionally, cfaf,
# Nearest to professional: kwanzaa, ti, therapeutae, alves, botswana, weighing, belonged, deco,
# Nearest to file: fruitarians, forging, reliable, broadest, muon, mishneh, occurs, cataract,
# Nearest to universe: indeed, lussac, medved, geddes, applying, occurrence, focal, glial,
# Nearest to nobel: statesman, recipient, blg, politician, universals, richard, rapper, violinist,
# Nearest to operations: mascarenhas, turns, quickened, eurocard, retracted, medulla, avogadro, bra,
# Nearest to primarily: graze, iq, fast, prozac, withholding, glycogen, sarcastically, donatien,
# Nearest to square: deviations, cemetery, arbitrary, clamp, nasa, ricks, pozna, hadadezer,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4960 0.2499 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4638 0.2461 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4564 0.2409 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5158 0.2454 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5056 0.2430 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4649 0.2429 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4638 0.2469 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3847 0.2327 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4021 0.2231 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4309 0.2383 sec/batch
# Nearest to years: constrain, outweighs, serendip, mariners, tangent, compares, fountain, heckman,
# Nearest to its: multiplying, europe, katydid, flavoured, bihar, epidemiology, compresses, lepidoptera,
# Nearest to about: resigning, colossians, elis, pitched, trickster, malignancies, zambia, truffles,
# Nearest to one: four, eight, zero, born, york, five, bough, latinos,
# Nearest to was: including, november, abstained, dead, peacecraft, australia, secure, contractually,
# Nearest to an: cheeses, dimensions, mandate, unusual, database, ingres, posed, satisfying,
# Nearest to is: somewhat, consumption, denoted, revisionist, we, actinopterygii, number, optimization,
# Nearest to only: yorkers, mtr, faithful, eil, subtext, steinitz, carabiners, recipients,
# Nearest to joseph: ups, hammerstein, uncanny, naturalist, exceptionally, ancien, clunies, dealbata,
# Nearest to professional: kwanzaa, ti, botswana, therapeutae, alves, deco, belonged, continuously,
# Nearest to file: fruitarians, reliable, forging, muon, compact, broadcasting, hitman, computer,
# Nearest to universe: indeed, applying, lussac, occurrence, glial, looksmart, medved, geddes,
# Nearest to nobel: statesman, recipient, blg, universals, violinist, politician, richard, hearted,
# Nearest to operations: mascarenhas, medulla, eurocard, quickened, turns, avogadro, corollaries, retracted,
# Nearest to primarily: iq, fast, graze, glycogen, prozac, sarcastically, maltose, donatien,
# Nearest to square: deviations, clamp, cemetery, blackbird, northernmost, nasa, hadadezer, arbitrary,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4185 0.2451 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4141 0.2437 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4309 0.2483 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3869 0.2433 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4109 0.2319 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4217 0.2328 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4137 0.2603 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3799 0.2496 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4228 0.2449 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3768 0.2486 sec/batch
# Nearest to years: constrain, outweighs, serendip, compares, mariners, tangent, ciar, fountain,
# Nearest to its: multiplying, europe, flavoured, katydid, bihar, compresses, poincar, lepidoptera,
# Nearest to about: resigning, elis, colossians, pitched, truffles, malignancies, trickster, zambia,
# Nearest to one: four, eight, zero, five, six, born, nine, gustave,
# Nearest to was: including, abstained, dead, november, ohl, peacecraft, success, zoetrope,
# Nearest to an: cheeses, dimensions, database, unusual, ingres, mandate, posed, satisfying,
# Nearest to is: denoted, somewhat, we, actinopterygii, anodes, number, females, designing,
# Nearest to only: yorkers, mtr, subtext, eil, cuny, faithful, permit, carabiners,
# Nearest to joseph: ups, hammerstein, raleigh, uncanny, naturalist, ancien, dealbata, clunies,
# Nearest to professional: kwanzaa, botswana, ti, therapeutae, alves, deco, fans, andrei,
# Nearest to file: fruitarians, reliable, forging, hitman, computer, muon, debug, broadcasting,
# Nearest to universe: indeed, applying, lussac, medved, occurrence, glial, geddes, looksmart,
# Nearest to nobel: statesman, recipient, blg, politician, violinist, universals, richard, chemist,
# Nearest to operations: eurocard, medulla, mascarenhas, umbra, quickened, corollaries, turns, benches,
# Nearest to primarily: graze, iq, sarcastically, fast, glycogen, prozac, glissandi, strabismus,
# Nearest to square: clamp, nasa, cemetery, blackbird, deviations, arbitrary, northernmost, hadadezer,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3584 0.2408 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3590 0.2331 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3648 0.2512 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3421 0.2509 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3644 0.2425 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3870 0.2443 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3516 0.2351 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3868 0.2432 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3374 0.2466 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3011 0.2470 sec/batch
# Nearest to years: constrain, serendip, outweighs, compares, tangent, mariners, aquariums, ciar,
# Nearest to its: europe, katydid, multiplying, compresses, flavoured, bihar, controlled, plumage,
# Nearest to about: resigning, elis, colossians, trickster, malignancies, anomie, bicoid, pitched,
# Nearest to one: four, zero, eight, five, six, two, nine, born,
# Nearest to was: including, abstained, november, ohl, dead, zoetrope, restored, the,
# Nearest to an: cheeses, mandate, database, unusual, dimensions, posed, ingres, detail,
# Nearest to is: somewhat, denoted, anodes, we, actinopterygii, females, number, revisionist,
# Nearest to only: mtr, eil, yorkers, faithful, subtext, cuny, permit, abnormality,
# Nearest to joseph: hammerstein, ups, uncanny, naturalist, raleigh, ancien, cfaf, clunies,
# Nearest to professional: kwanzaa, ti, botswana, therapeutae, deco, alves, continuously, allow,
# Nearest to file: fruitarians, reliable, forging, computer, debug, hitman, newsletter, lorenz,
# Nearest to universe: indeed, lussac, metastable, medved, applying, geddes, glial, looksmart,
# Nearest to nobel: recipient, statesman, blg, universals, violinist, pecos, hess, chemist,
# Nearest to operations: eurocard, umbra, medulla, mascarenhas, corollaries, benches, avogadro, customizing,
# Nearest to primarily: graze, reduced, iq, glycogen, sarcastically, glissandi, prozac, maltose,
# Nearest to square: nasa, cemetery, northernmost, clamp, blackbird, hadadezer, loess, sq,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3243 0.2531 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3056 0.2492 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3609 0.2417 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4115 0.2496 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3900 0.2494 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2624 0.2415 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2759 0.2385 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3303 0.2387 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2480 0.2434 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2915 0.2418 sec/batch
# Nearest to years: constrain, outweighs, fertility, male, serendip, mortality, female, migrant,
# Nearest to its: europe, katydid, bihar, multiplying, flavoured, compresses, controlled, adjustment,
# Nearest to about: resigning, trickster, elis, zambia, malignancies, bicoid, colossians, anomie,
# Nearest to one: four, zero, eight, five, six, nine, two, born,
# Nearest to was: abstained, november, including, dead, zoetrope, chief, woolworth, buckinghamshire,
# Nearest to an: mandate, cheeses, database, portmanteaus, ingres, therein, topology, unusual,
# Nearest to is: denoted, somewhat, females, actinopterygii, we, anodes, commutativity, revisionist,
# Nearest to only: mtr, eil, faithful, yorkers, cuny, permit, subtext, singers,
# Nearest to joseph: hammerstein, uncanny, naturalist, ups, cfaf, clunies, ancien, testaments,
# Nearest to professional: kwanzaa, ti, therapeutae, botswana, alves, deco, fans, shaughnessy,
# Nearest to file: fruitarians, forging, reliable, debug, computer, hitman, newsletter, stoll,
# Nearest to universe: indeed, lussac, medved, glial, euhemerus, geddes, metastable, applying,
# Nearest to nobel: recipient, statesman, violinist, physiology, chemist, hess, politician, blg,
# Nearest to operations: eurocard, umbra, mascarenhas, medulla, benches, clis, corollaries, equuleus,
# Nearest to primarily: graze, sarcastically, iq, glissandi, reduced, glycogen, dachshunds, olde,
# Nearest to square: cemetery, nasa, blackbird, northernmost, hadadezer, clamp, radius, loess,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2756 0.2398 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2954 0.2502 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3193 0.1135 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2286 0.2393 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2231 0.2494 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2242 0.2518 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2010 0.2482 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1894 0.2492 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2016 0.2458 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1408 0.2488 sec/batch
# Nearest to years: outweighs, serendip, constrain, fertility, male, mortality, migrant, rate,
# Nearest to its: europe, katydid, multiplying, bihar, flavoured, lepidoptera, resonator, controlled,
# Nearest to about: zambia, resigning, trickster, elis, malignancies, anomie, bornholm, bicoid,
# Nearest to one: four, zero, eight, five, two, six, nine, seven,
# Nearest to was: november, abstained, including, dead, woolworth, had, zoetrope, buckinghamshire,
# Nearest to an: mandate, cheeses, unusual, portmanteaus, ingres, posed, tester, cummins,
# Nearest to is: actinopterygii, somewhat, denoted, alkynes, females, number, commutativity, surrounding,
# Nearest to only: mtr, eil, yorkers, cuny, permit, faithful, subtext, carabiners,
# Nearest to joseph: hammerstein, naturalist, uncanny, ups, testaments, cfaf, clunies, ancien,
# Nearest to professional: kwanzaa, deco, botswana, ti, fans, therapeutae, shaughnessy, allow,
# Nearest to file: fruitarians, forging, debug, hitman, stoll, reliable, connector, istria,
# Nearest to universe: indeed, lussac, medved, glial, euhemerus, metastable, geddes, grammaticus,
# Nearest to nobel: recipient, statesman, physiology, hess, violinist, blg, chemist, politician,
# Nearest to operations: eurocard, umbra, equuleus, medulla, causally, mascarenhas, avogadro, colspan,
# Nearest to primarily: graze, glissandi, iq, glycogen, dachshunds, reduced, sarcastically, strabismus,
# Nearest to square: cemetery, blackbird, radius, clamp, deciduous, northernmost, nasa, hadadezer,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2257 0.2505 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2076 0.2412 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2299 0.2487 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1138 0.2460 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1700 0.2486 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1325 0.2489 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1466 0.2480 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1626 0.2461 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1823 0.2427 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1379 0.2433 sec/batch
# Nearest to years: serendip, constrain, outweighs, mortality, male, fertility, rate, migrant,
# Nearest to its: multiplying, katydid, europe, resonator, bihar, flavoured, lepidoptera, bleda,
# Nearest to about: resigning, trickster, malignancies, truffles, anomie, zambia, membranes, colossians,
# Nearest to one: four, zero, eight, five, six, two, nine, three,
# Nearest to was: november, including, abstained, dead, woolworth, success, had, synchronous,
# Nearest to an: mandate, unusual, cheeses, portmanteaus, overillumination, ingres, cummins, posed,
# Nearest to is: denoted, all, somewhat, number, we, actinopterygii, or, commutativity,
# Nearest to only: yorkers, cuny, eil, mtr, permit, faithful, hour, subtext,
# Nearest to joseph: uncanny, ups, hammerstein, testaments, naturalist, cfaf, exceptionally, novella,
# Nearest to professional: deco, botswana, kwanzaa, ti, kao, therapeutae, fans, shaughnessy,
# Nearest to file: fruitarians, forging, debug, hitman, computer, reliable, istria, stoll,
# Nearest to universe: euhemerus, indeed, lussac, medved, glial, metastable, vav, grammaticus,
# Nearest to nobel: recipient, statesman, violinist, hess, blg, physiology, chemist, universals,
# Nearest to operations: eurocard, umbra, equuleus, medulla, clis, patrol, causally, benches,
# Nearest to primarily: glissandi, iq, graze, glycogen, dachshunds, reduced, sarcastically, servile,
# Nearest to square: cemetery, blackbird, coordinates, radius, clamp, northernmost, deciduous, nasa,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1026 0.2523 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2188 0.2416 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1532 0.2450 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1208 0.2503 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1467 0.2443 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1481 0.2441 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1653 0.2402 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1315 0.2406 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1098 0.2550 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1525 0.2452 sec/batch
# Nearest to years: constrain, serendip, outweighs, fertility, male, mortality, rate, children,
# Nearest to its: multiplying, katydid, europe, resonator, bihar, poincar, bleda, compressibility,
# Nearest to about: trickster, resigning, anomie, malignancies, external, truffles, zambia, bornholm,
# Nearest to one: four, zero, eight, five, nine, two, six, seven,
# Nearest to was: including, november, abstained, stepmother, success, had, dead, noguchi,
# Nearest to an: mandate, portmanteaus, unusual, evenly, rational, ingres, posed, overillumination,
# Nearest to is: denoted, commutativity, all, somewhat, we, actinopterygii, number, anodes,
# Nearest to only: cuny, yorkers, eil, mtr, faithful, subtext, permit, succession,
# Nearest to joseph: hammerstein, naturalist, uncanny, testaments, ups, cfaf, exceptionally, clunies,
# Nearest to professional: deco, kwanzaa, botswana, arts, kao, therapeutae, shaughnessy, ti,
# Nearest to file: fruitarians, forging, debug, hitman, page, stoll, lindemann, message,
# Nearest to universe: euhemerus, indeed, lussac, medved, emits, glial, metastable, grammaticus,
# Nearest to nobel: recipient, physiology, hess, statesman, violinist, blg, chemist, pecos,
# Nearest to operations: eurocard, umbra, warship, equuleus, clis, patrol, mascarenhas, medulla,
# Nearest to primarily: glissandi, iq, graze, dachshunds, servile, sarcastically, reduced, glycogen,
# Nearest to square: cemetery, blackbird, clamp, radius, coordinates, arbitrary, northernmost, measured,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1634 0.2559 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1750 0.2354 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1273 0.2404 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1522 0.2436 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1308 0.2444 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1089 0.2442 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1332 0.2413 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1155 0.2414 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1832 0.2466 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2137 0.2412 sec/batch
# Nearest to years: outweighs, serendip, constrain, fertility, rate, age, male, children,
# Nearest to its: europe, katydid, multiplying, bihar, kwahu, bleda, kiel, lepidoptera,
# Nearest to about: resigning, trickster, anomie, elis, external, pba, zambia, bornholm,
# Nearest to one: four, zero, eight, five, nine, six, two, seven,
# Nearest to was: november, had, abstained, including, success, fontane, met, tiberius,
# Nearest to an: mandate, portmanteaus, cummins, posed, ingres, horowitz, merrick, evenly,
# Nearest to is: all, commutativity, denoted, somewhat, urville, actinopterygii, females, we,
# Nearest to only: eil, faithful, cuny, succession, mlb, yorkers, mtr, upon,
# Nearest to joseph: exceptionally, uncanny, testaments, hammerstein, naturalist, ups, cfaf, clunies,
# Nearest to professional: deco, kwanzaa, botswana, therapeutae, kao, shaughnessy, ti, arts,
# Nearest to file: fruitarians, forging, debug, hitman, stoll, newsletter, lindemann, page,
# Nearest to universe: euhemerus, medved, indeed, lussac, grammaticus, glial, shading, emits,
# Nearest to nobel: recipient, physiology, hess, violinist, chemist, statesman, blg, pecos,
# Nearest to operations: umbra, eurocard, patrol, warship, equuleus, clis, conscripted, cp,
# Nearest to primarily: glissandi, iq, graze, dachshunds, reduced, servile, glycogen, sarcastically,
# Nearest to square: cemetery, blackbird, northernmost, clamp, arbitrary, pillaging, coordinates, radius,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2317 0.2518 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0900 0.2550 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1146 0.2688 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1195 0.2591 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0161 0.2590 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1297 0.2766 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1317 0.2778 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1070 0.2573 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1719 0.0493 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1148 0.2614 sec/batch
# Nearest to years: rate, fertility, mortality, outweighs, male, migrant, constrain, serendip,
# Nearest to its: katydid, multiplying, europe, bihar, bleda, resonator, developed, lepidoptera,
# Nearest to about: resigning, trickster, zambia, anomie, external, elis, pba, workspace,
# Nearest to one: four, zero, eight, five, two, nine, six, three,
# Nearest to was: november, had, including, abstained, success, noguchi, eleonore, led,
# Nearest to an: mandate, portmanteaus, cummins, terms, ingres, rational, unusual, evenly,
# Nearest to is: denoted, number, commutativity, actinopterygii, the, or, all, females,
# Nearest to only: eil, faithful, cuny, mtr, singers, succession, permit, carabiners,
# Nearest to joseph: naturalist, uncanny, testaments, ups, hammerstein, exceptionally, cfaf, clunies,
# Nearest to professional: deco, arts, therapeutae, kwanzaa, training, ti, botswana, kao,
# Nearest to file: fruitarians, debug, forging, files, stoll, message, hitman, istria,
# Nearest to universe: euhemerus, medved, indeed, lussac, shading, glial, grammaticus, emits,
# Nearest to nobel: recipient, physiology, hess, chemist, blg, violinist, webelements, statesman,
# Nearest to operations: umbra, eurocard, patrol, warship, equuleus, cp, clis, freeciv,
# Nearest to primarily: glissandi, iq, graze, servile, dachshunds, trinidad, lir, multistage,
# Nearest to square: cemetery, blackbird, clamp, northernmost, coordinates, pillaging, deciduous, radius,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0572 0.2606 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0641 0.2579 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0843 0.2570 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0202 0.2588 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0224 0.2575 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0001 0.2574 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0836 0.2596 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0445 0.2560 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0845 0.2577 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9780 0.2572 sec/batch
# Nearest to years: rate, serendip, outweighs, migrant, male, fertility, mortality, female,
# Nearest to its: multiplying, katydid, bleda, lepidoptera, developed, resonator, kwahu, bihar,
# Nearest to about: trickster, zambia, external, resigning, bornholm, workspace, astronomers, landsat,
# Nearest to one: four, zero, eight, five, two, nine, six, seven,
# Nearest to was: november, had, including, abstained, success, noguchi, led, eleonore,
# Nearest to an: mandate, cummins, evenly, portmanteaus, unusual, rallying, least, counterculture,
# Nearest to is: denoted, all, or, affine, number, commutativity, actinopterygii, the,
# Nearest to only: eil, faithful, mlb, succession, cuny, permit, when, mtr,
# Nearest to joseph: uncanny, testaments, ups, naturalist, exceptionally, clunies, cfaf, hammerstein,
# Nearest to professional: deco, botswana, training, arts, kao, kwanzaa, therapeutae, shaughnessy,
# Nearest to file: fruitarians, forging, debug, files, stoll, workbench, hitman, vse,
# Nearest to universe: euhemerus, indeed, emits, metastable, matter, glial, lussac, medved,
# Nearest to nobel: recipient, physiology, hess, violinist, prize, chemist, blg, webelements,
# Nearest to operations: umbra, eurocard, warship, patrol, equuleus, variances, knives, cp,
# Nearest to primarily: glissandi, iq, graze, servile, glycogen, modal, lir, dachshunds,
# Nearest to square: cemetery, blackbird, northernmost, clamp, arbitrary, radius, coordinates, watersheds,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9839 0.2641 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0087 0.2573 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9574 0.2603 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0224 0.2686 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0460 0.2657 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0295 0.2645 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0266 0.2680 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0651 0.2653 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0379 0.2642 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0082 0.2694 sec/batch
# Nearest to years: serendip, rate, age, migrant, male, female, mortality, fertility,
# Nearest to its: multiplying, katydid, resonator, bleda, obispo, lepidoptera, kwahu, bihar,
# Nearest to about: trickster, external, truffles, pba, astronomers, zambia, resigning, workspace,
# Nearest to one: four, zero, eight, five, nine, two, six, seven,
# Nearest to was: november, had, including, abstained, noguchi, eleonore, stepmother, success,
# Nearest to an: mandate, unusual, portmanteaus, evenly, rational, overillumination, nonpolar, counterculture,
# Nearest to is: all, denoted, commutativity, affine, the, we, or, number,
# Nearest to only: succession, faithful, mlb, permit, read, eil, dukedom, cuny,
# Nearest to joseph: uncanny, testaments, exceptionally, ups, proxies, colossians, naturalist, hammerstein,
# Nearest to professional: deco, training, botswana, arts, therapeutae, kao, kwanzaa, maleev,
# Nearest to file: fruitarians, forging, debug, files, stoll, vse, workbench, hitman,
# Nearest to universe: euhemerus, indeed, emits, matter, medved, bang, grammaticus, metastable,
# Nearest to nobel: recipient, physiology, chemist, hess, violinist, prize, webelements, statesman,
# Nearest to operations: umbra, eurocard, warship, patrol, equuleus, knives, cp, conscripted,
# Nearest to primarily: glissandi, graze, iq, servile, modal, multistage, dachshunds, glycogen,
# Nearest to square: cemetery, blackbird, arbitrary, clamp, radius, coordinates, pillaging, majapahit,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0460 0.2657 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0670 0.2724 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0452 0.2633 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0257 0.2654 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0215 0.2636 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0104 0.2657 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0304 0.2648 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0059 0.2653 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0540 0.2647 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0322 0.2645 sec/batch
# Nearest to years: rate, serendip, age, male, migrant, children, female, constrain,
# Nearest to its: katydid, multiplying, kwahu, bleda, was, lepidoptera, europe, resonator,
# Nearest to about: trickster, pba, zambia, astronomers, resigning, workspace, external, landsat,
# Nearest to one: four, zero, two, five, eight, nine, six, seven,
# Nearest to was: november, had, abstained, the, including, until, led, stepmother,
# Nearest to an: portmanteaus, mandate, evenly, rallying, unusual, overillumination, counterculture, nonpolar,
# Nearest to is: all, or, commutativity, somewhat, denoted, affine, the, we,
# Nearest to only: faithful, succession, mlb, permit, carabiners, eil, cuny, read,
# Nearest to joseph: testaments, naturalist, exceptionally, ups, proxies, uncanny, blaise, colossians,
# Nearest to professional: deco, arts, training, botswana, therapeutae, shaughnessy, kao, kwanzaa,
# Nearest to file: fruitarians, debug, forging, files, stoll, vse, workbench, istria,
# Nearest to universe: euhemerus, emits, indeed, bang, medved, metastable, grammaticus, matter,
# Nearest to nobel: recipient, physiology, hess, violinist, webelements, chemist, ment, blg,
# Nearest to operations: umbra, warship, knives, eurocard, patrol, equuleus, conscripted, cp,
# Nearest to primarily: glissandi, iq, servile, graze, modal, sarcastically, glycogen, turkmen,
# Nearest to square: cemetery, blackbird, clamp, arbitrary, radius, pillaging, coordinates, deviations,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0453 0.2670 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9941 0.2646 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9853 0.2882 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0433 0.2651 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0487 0.2701 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0668 0.2649 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0959 0.2629 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0131 0.2642 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9936 0.2677 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0182 0.2810 sec/batch
# Nearest to years: rate, age, children, serendip, migrant, male, female, outweighs,
# Nearest to its: katydid, kwahu, multiplying, bihar, bleda, lepidoptera, kiel, europe,
# Nearest to about: trickster, resigning, pba, external, zambia, workspace, bicoid, astronomers,
# Nearest to one: four, zero, five, eight, nine, two, six, seven,
# Nearest to was: november, had, including, abstained, murat, led, his, who,
# Nearest to an: portmanteaus, mandate, evenly, rallying, cummins, counterculture, overillumination, alphonzo,
# Nearest to is: the, affine, or, commutativity, denoted, actinopterygii, arcseconds, all,
# Nearest to only: faithful, mlb, eil, succession, permit, dukedom, upon, when,
# Nearest to joseph: testaments, exceptionally, ups, naturalist, proxies, uncanny, clunies, colossians,
# Nearest to professional: training, deco, arts, botswana, therapeutae, kao, shaughnessy, maleev,
# Nearest to file: fruitarians, forging, stoll, debug, files, vse, istria, lys,
# Nearest to universe: euhemerus, emits, medved, grammaticus, indeed, bang, series, simulations,
# Nearest to nobel: recipient, physiology, prize, hess, webelements, woodcock, violinist, ment,
# Nearest to operations: umbra, warship, knives, patrol, eurocard, equuleus, cp, conscripted,
# Nearest to primarily: glissandi, servile, iq, graze, modal, sarcastically, glycogen, lir,
# Nearest to square: cemetery, blackbird, clamp, arbitrary, pillaging, majapahit, radius, deciduous,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9417 0.2808 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0060 0.2663 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0054 0.2667 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9918 0.2653 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0203 0.2643 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9799 0.2431 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9659 0.2645 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9652 0.2500 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9885 0.2334 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9308 0.2155 sec/batch
# Nearest to years: serendip, rate, age, migrant, fertility, children, outweighs, male,
# Nearest to its: katydid, multiplying, kwahu, bleda, was, lepidoptera, bihar, commercial,
# Nearest to about: trickster, pba, zambia, external, bornholm, landsat, resigning, astronomers,
# Nearest to one: four, nine, zero, eight, five, two, seven, six,
# Nearest to was: had, including, november, abstained, multiplan, first, who, his,
# Nearest to an: portmanteaus, evenly, nonpolar, mandate, formalization, unusual, rallying, from,
# Nearest to is: the, actinopterygii, affine, or, arcseconds, commutativity, denoted, all,
# Nearest to only: faithful, succession, mlb, eil, upon, dukedom, when, permit,
# Nearest to joseph: naturalist, testaments, exceptionally, ups, nowak, proxies, uncanny, colossians,
# Nearest to professional: training, arts, deco, kao, therapeutae, botswana, tarrant, maleev,
# Nearest to file: fruitarians, stoll, files, forging, debug, vse, istria, workbench,
# Nearest to universe: euhemerus, emits, medved, bang, simulations, series, indeed, stupid,
# Nearest to nobel: recipient, violinist, hess, physiology, prize, webelements, woodcock, chemist,
# Nearest to operations: warship, knives, umbra, patrol, equuleus, eurocard, saunders, bra,
# Nearest to primarily: glissandi, iq, servile, graze, modal, glycogen, lir, trinidad,
# Nearest to square: cemetery, blackbird, clamp, pillaging, deciduous, ravine, coordinates, majapahit,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9515 0.2170 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9023 0.2150 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9673 0.2158 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9658 0.2164 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9833 0.2155 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9419 0.2150 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8519 0.2161 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9105 0.2144 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8669 0.2141 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9014 0.2150 sec/batch
# Nearest to years: rate, age, male, serendip, migrant, mariners, children, expectancy,
# Nearest to its: katydid, multiplying, kwahu, bleda, lepidoptera, obispo, commercial, bihar,
# Nearest to about: trickster, external, truffles, zambia, landsat, bornholm, workspace, pba,
# Nearest to one: four, zero, eight, two, nine, five, six, three,
# Nearest to was: had, including, november, who, multiplan, abstained, eleonore, success,
# Nearest to an: evenly, from, rallying, mandate, unusual, portmanteaus, alphonzo, cummins,
# Nearest to is: the, or, all, affine, as, number, actinopterygii, denoted,
# Nearest to only: mlb, succession, when, faithful, upon, read, permit, eil,
# Nearest to joseph: testaments, proxies, exceptionally, ups, colossians, gesture, uncanny, anabaptism,
# Nearest to professional: training, arts, botswana, deco, kao, therapeutae, modified, saloons,
# Nearest to file: files, stoll, fruitarians, forging, debug, vse, workbench, istria,
# Nearest to universe: euhemerus, bang, emits, simulations, matter, metastable, indeed, series,
# Nearest to nobel: recipient, webelements, hess, violinist, physiology, prize, woodcock, blg,
# Nearest to operations: warship, knives, umbra, patrol, saunders, equuleus, eurocard, cp,
# Nearest to primarily: glissandi, iq, graze, glycogen, modal, servile, lir, multistage,
# Nearest to square: cemetery, blackbird, coordinates, clamp, arbitrary, deciduous, pillaging, majapahit,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9513 0.2162 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9560 0.2145 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9500 0.2157 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9535 0.2164 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0086 0.2148 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8839 0.2154 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9346 0.2154 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9451 0.2158 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9633 0.2149 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9546 0.2150 sec/batch
# Nearest to years: age, rate, serendip, male, mariners, children, expectancy, migrant,
# Nearest to its: katydid, multiplying, kwahu, obispo, lepidoptera, bleda, was, commercial,
# Nearest to about: trickster, resigning, pba, summertime, external, truffles, zambia, ndm,
# Nearest to one: four, eight, nine, zero, two, five, six, seven,
# Nearest to was: had, including, eleonore, november, who, his, success, first,
# Nearest to an: evenly, from, formalization, rallying, portmanteaus, unusual, counterculture, tithe,
# Nearest to is: the, affine, as, or, all, we, does, commutativity,
# Nearest to only: mlb, succession, faithful, when, read, upon, dukedom, permit,
# Nearest to joseph: blaise, testaments, proxies, exceptionally, naturalist, capell, colossians, ups,
# Nearest to professional: training, arts, deco, kao, botswana, therapeutae, saloons, tarrant,
# Nearest to file: files, stoll, fruitarians, forging, debug, vse, divide, worms,
# Nearest to universe: euhemerus, bang, simulations, emits, series, matter, dune, wavelength,
# Nearest to nobel: recipient, physiology, webelements, prize, hess, violinist, woodcock, chemist,
# Nearest to operations: warship, knives, umbra, patrol, saunders, cp, subtract, conscripted,
# Nearest to primarily: glissandi, iq, servile, graze, modal, glycogen, lir, sarcastically,
# Nearest to square: cemetery, blackbird, arbitrary, clamp, pillaging, coordinates, deciduous, ravine,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9784 0.2171 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9589 0.2161 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9047 0.2162 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9779 0.2156 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9961 0.2150 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9910 0.2155 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9224 0.2151 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9118 0.2169 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9446 0.2155 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9861 0.2153 sec/batch
# Nearest to years: rate, age, migrant, male, expectancy, female, fertility, live,
# Nearest to its: was, katydid, kwahu, multiplying, ifad, kiel, bleda, redefined,
# Nearest to about: trickster, external, pba, planetarium, information, bornholm, resigning, anomie,
# Nearest to one: four, eight, zero, two, nine, five, six, three,
# Nearest to was: had, november, including, its, discovered, abstained, eleonore, first,
# Nearest to an: from, evenly, the, of, portmanteaus, tripartite, rallying, tithe,
# Nearest to is: the, or, as, affine, does, we, be, if,
# Nearest to only: upon, succession, mlb, when, faithful, permit, dukedom, read,
# Nearest to joseph: proxies, blaise, ups, colossians, testaments, exceptionally, gesture, naturalist,
# Nearest to professional: training, arts, deco, modified, kao, botswana, therapeutae, saloons,
# Nearest to file: files, stoll, fruitarians, forging, debug, vse, divide, istria,
# Nearest to universe: euhemerus, bang, simulations, series, emits, dune, indeed, ethereal,
# Nearest to nobel: recipient, webelements, prize, physiology, hess, violinist, chesterton, woodcock,
# Nearest to operations: warship, knives, umbra, patrol, saunders, hence, equuleus, cp,
# Nearest to primarily: glissandi, servile, modal, iq, graze, glycogen, turkmen, lir,
# Nearest to square: cemetery, blackbird, pillaging, arbitrary, deciduous, clamp, ravine, majapahit,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9382 0.2168 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0869 0.2147 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 3.9853 0.2154 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 3.9721 0.2144 sec/batch
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7192 0.2159 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7697 0.2156 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7829 0.2143 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8138 0.2153 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7752 0.2148 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8422 0.2145 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8444 0.2146 sec/batch
# Nearest to years: age, year, live, lived, life, eight, rate, female,
# Nearest to its: was, it, the, a, lepidoptera, multiplying, s, unisys,
# Nearest to about: information, heawood, reporters, planetarium, trickster, nonnus, jill, documented,
# Nearest to one: four, two, nine, three, eight, five, seven, zero,
# Nearest to was: had, in, it, its, discovered, first, named, happened,
# Nearest to an: a, the, for, from, called, as, in, of,
# Nearest to is: the, of, a, as, or, in, it, this,
# Nearest to only: read, which, to, when, since, all, of, upon,
# Nearest to joseph: proxies, colossians, capell, ups, ancien, prophet, darcy, naturalist,
# Nearest to professional: training, arts, kao, modified, belonged, trained, tarrant, therapeutae,
# Nearest to file: files, fruitarians, stoll, lys, filename, forging, divide, imaginable,
# Nearest to universe: cosmology, simulations, ethereal, create, bussard, voids, matter, euhemerus,
# Nearest to nobel: prize, recipient, laureate, physiology, violinist, elie, laureates, mandelstam,
# Nearest to operations: warship, saunders, knives, ormers, commando, citigroup, pontificia, patrol,
# Nearest to primarily: glissandi, modal, glycogen, reduced, servile, iq, infiltrated, dfs,
# Nearest to square: cemetery, measured, entr, earners, clamp, arbitrary, manson, deviations,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7643 0.2163 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8124 0.2147 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8050 0.2150 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8051 0.2149 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7813 0.2151 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8560 0.2146 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8208 0.2157 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7530 0.2159 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8359 0.2154 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8231 0.2152 sec/batch
# Nearest to years: age, eight, year, rate, lived, live, migrant, life,
# Nearest to its: it, was, the, a, lepidoptera, s, redefined, of,
# Nearest to about: information, reporters, heawood, documented, redshift, planetarium, historical, experimentation,
# Nearest to one: four, two, nine, three, eight, zero, five, seven,
# Nearest to was: had, in, its, first, discovered, he, his, it,
# Nearest to an: a, the, for, from, called, as, is, in,
# Nearest to is: the, as, of, a, by, or, it, in,
# Nearest to only: read, to, based, when, since, which, some, upon,
# Nearest to joseph: proxies, colossians, capell, blaise, sons, ancien, ups, naturalist,
# Nearest to professional: training, arts, kao, belonged, modified, therapeutae, tarrant, discipline,
# Nearest to file: files, fruitarians, filename, compressed, lys, stoll, forging, imaginable,
# Nearest to universe: cosmology, simulations, ethereal, voids, create, bussard, euhemerus, matter,
# Nearest to nobel: prize, recipient, laureate, elie, physiology, laureates, vertebrate, violinist,
# Nearest to operations: warship, saunders, knives, ormers, pontificia, commando, hyperreal, citigroup,
# Nearest to primarily: glissandi, reduced, servile, glycogen, modal, turkmen, used, infiltrated,
# Nearest to square: cemetery, earners, deviations, entr, manson, measured, arbitrary, parameters,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8247 0.2178 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7774 0.2157 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7705 0.2145 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7699 0.2146 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8407 0.2154 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8037 0.2156 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9211 0.2147 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8641 0.2141 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8679 0.2158 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8021 0.2147 sec/batch
# Nearest to years: age, year, eight, rate, life, live, female, infant,
# Nearest to its: the, it, was, a, s, of, kwahu, lepidoptera,
# Nearest to about: information, reporters, chats, documented, external, planetarium, heawood, eesti,
# Nearest to one: four, two, nine, three, eight, five, seven, zero,
# Nearest to was: had, in, first, he, discovered, its, the, it,
# Nearest to an: a, the, for, in, from, of, as, called,
# Nearest to is: the, of, a, as, or, this, an, by,
# Nearest to only: read, which, to, since, some, upon, based, theism,
# Nearest to joseph: proxies, sons, blaise, ancien, naturalist, capell, colossians, darcy,
# Nearest to professional: training, arts, kao, belonged, modified, therapeutae, trained, tarrant,
# Nearest to file: files, fruitarians, forging, filename, lys, stoll, imaginable, compressed,
# Nearest to universe: cosmology, simulations, ethereal, voids, euhemerus, create, bussard, matter,
# Nearest to nobel: prize, recipient, laureate, physiology, elie, laureates, violinist, vertebrate,
# Nearest to operations: warship, knives, saunders, pontificia, commando, hyperreal, patrol, avars,
# Nearest to primarily: glissandi, servile, glycogen, reduced, infiltrated, modal, barter, singapore,
# Nearest to square: cemetery, earners, which, entr, manson, approximately, measured, parameters,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7075 0.2172 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8047 0.2147 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7188 0.2147 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8170 0.2139 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7794 0.2147 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7997 0.2148 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8543 0.1228 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8047 0.2151 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7763 0.2155 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.7907 0.2155 sec/batch
# Nearest to years: year, age, rate, life, live, female, migrant, eight,
# Nearest to its: it, was, the, a, s, redefined, lepidoptera, kwahu,
# Nearest to about: information, planetarium, heawood, redshift, toklas, reporters, nonnus, documented,
# Nearest to one: four, two, nine, three, eight, seven, five, zero,
# Nearest to was: had, in, first, a, discovered, and, its, the,
# Nearest to an: a, the, for, in, from, of, called, is,
# Nearest to is: the, of, as, a, in, or, this, an,
# Nearest to only: to, read, which, some, all, upon, based, of,
# Nearest to joseph: proxies, sons, darcy, capell, blaise, naturalist, ancien, prophet,
# Nearest to professional: training, kao, arts, therapeutae, trained, modified, belonged, sahib,
# Nearest to file: files, fruitarians, stoll, filename, lys, compressed, forging, usaid,
# Nearest to universe: cosmology, voids, simulations, ethereal, create, euhemerus, matter, bussard,
# Nearest to nobel: prize, recipient, laureate, physiology, elie, violinist, laureates, decorations,
# Nearest to operations: warship, knives, saunders, hyperreal, pontificia, ormers, patrol, deconstructive,
# Nearest to primarily: glissandi, modal, servile, glycogen, iq, reduced, used, tend,
# Nearest to square: cemetery, earners, approximately, depressed, entr, pentagons, parameters, which,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7654 0.2168 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7560 0.2153 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7837 0.2158 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7489 0.2154 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7882 0.2157 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7547 0.2156 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8216 0.2157 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6914 0.2147 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7462 0.2150 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7444 0.2144 sec/batch
# Nearest to years: age, year, eight, life, rate, female, live, migrant,
# Nearest to its: it, the, a, was, s, also, of, in,
# Nearest to about: information, reporters, toklas, heawood, descended, planetarium, sweeteners, lipolysis,
# Nearest to one: four, two, nine, three, eight, seven, five, zero,
# Nearest to was: had, in, first, its, it, discovered, later, he,
# Nearest to an: a, for, the, from, is, called, as, in,
# Nearest to is: the, of, a, in, as, it, this, or,
# Nearest to only: read, to, which, in, some, all, of, is,
# Nearest to joseph: proxies, sons, prophet, colossians, darcy, blaise, ancien, clearest,
# Nearest to professional: training, kao, arts, modified, therapeutae, trained, belonged, reforms,
# Nearest to file: files, filename, fruitarians, lys, stoll, forging, compressed, usaid,
# Nearest to universe: cosmology, simulations, voids, ethereal, matter, bang, bussard, create,
# Nearest to nobel: prize, recipient, laureate, physiology, laureates, elie, violinist, decorations,
# Nearest to operations: warship, knives, saunders, hyperreal, pontificia, ormers, avars, patrol,
# Nearest to primarily: glissandi, servile, modal, glycogen, used, reduced, for, coelacanth,
# Nearest to square: cemetery, parameters, entr, approximately, pentagons, hexagonal, deviations, depressed,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6930 0.2171 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7698 0.2153 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7857 0.2149 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7775 0.2150 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7732 0.2156 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8592 0.2153 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8056 0.2163 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7593 0.2154 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7869 0.2156 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8033 0.2151 sec/batch
# Nearest to years: age, year, eight, rate, live, female, life, migrant,
# Nearest to its: the, it, a, was, s, of, also, in,
# Nearest to about: information, toklas, planetarium, reporters, redshift, heawood, descended, franca,
# Nearest to one: four, two, nine, three, eight, seven, zero, five,
# Nearest to was: in, had, first, s, its, been, his, the,
# Nearest to an: a, the, for, from, is, be, called, of,
# Nearest to is: the, of, a, it, as, this, in, or,
# Nearest to only: to, read, in, since, all, which, of, is,
# Nearest to joseph: proxies, sons, darcy, colossians, capell, blaise, naturalist, nowak,
# Nearest to professional: training, arts, kao, trained, modified, belonged, therapeutae, hurdler,
# Nearest to file: files, fruitarians, filename, compressed, lys, forging, stoll, imaginable,
# Nearest to universe: cosmology, ethereal, voids, simulations, matter, bussard, create, bang,
# Nearest to nobel: prize, recipient, laureate, physiology, laureates, elie, violinist, decorations,
# Nearest to operations: warship, knives, saunders, ormers, avars, pontificia, patrol, hyperreal,
# Nearest to primarily: glissandi, modal, servile, reduced, used, nnrot, glycogen, cryptanalyst,
# Nearest to square: cemetery, parameters, depressed, manson, entr, deviations, shown, arbitrary,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8063 0.2171 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7750 0.2156 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7958 0.2155 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7528 0.2167 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8080 0.2151 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8118 0.2160 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7539 0.2144 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8153 0.2146 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7387 0.2152 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7566 0.2148 sec/batch
# Nearest to years: age, year, rate, eight, life, live, female, migrant,
# Nearest to its: the, it, was, a, s, of, in, and,
# Nearest to about: information, planetarium, chats, descended, reporters, maori, toklas, education,
# Nearest to one: four, two, three, nine, seven, eight, five, zero,
# Nearest to was: in, had, its, the, first, it, been, by,
# Nearest to an: a, the, for, from, as, of, in, called,
# Nearest to is: the, of, a, in, as, it, or, this,
# Nearest to only: to, read, in, some, all, which, of, feature,
# Nearest to joseph: proxies, colossians, darcy, sons, blaise, ancien, capell, naturalist,
# Nearest to professional: training, kao, modified, arts, trained, therapeutae, done, belonged,
# Nearest to file: files, fruitarians, filename, compressed, forging, lys, usaid, imaginable,
# Nearest to universe: cosmology, ethereal, simulations, matter, voids, bussard, bang, corrado,
# Nearest to nobel: prize, recipient, laureate, laureates, elie, physiology, decorations, violinist,
# Nearest to operations: warship, knives, avars, patrol, hyperreal, ormers, commando, pontificia,
# Nearest to primarily: glissandi, for, reduced, servile, some, glycogen, the, infiltrated,
# Nearest to square: cemetery, depressed, entr, shown, manson, parameters, deviations, kilometer,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8045 0.2164 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7838 0.2156 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8881 0.2161 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8697 0.2150 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8162 0.2154 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7946 0.2156 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.6750 0.2151 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7876 0.2157 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6865 0.2149 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.7899 0.2152 sec/batch
# Nearest to years: year, age, rate, female, life, eight, migrant, zero,
# Nearest to its: the, it, a, was, s, of, also, which,
# Nearest to about: information, planetarium, reporters, maori, descended, nearly, education, chats,
# Nearest to one: four, nine, two, three, eight, seven, five, zero,
# Nearest to was: had, in, it, first, s, its, the, and,
# Nearest to an: a, the, for, in, from, is, of, as,
# Nearest to is: the, of, a, it, in, as, an, or,
# Nearest to only: to, which, read, all, some, even, of, in,
# Nearest to joseph: proxies, sons, colossians, darcy, prophet, ancien, blaise, cask,
# Nearest to professional: training, kao, trained, modified, therapeutae, arts, belonged, larisa,
# Nearest to file: files, fruitarians, filename, compressed, lys, forging, usaid, stoll,
# Nearest to universe: cosmology, ethereal, voids, matter, bussard, simulations, bang, create,
# Nearest to nobel: prize, recipient, laureate, physiology, laureates, elie, decorations, violinist,
# Nearest to operations: warship, hyperreal, patrol, knives, avars, pontificia, ormers, saunders,
# Nearest to primarily: glissandi, servile, some, for, modal, reduced, glycogen, tend,
# Nearest to square: which, cemetery, depressed, entr, manson, kilometer, parameters, shown,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7894 0.2169 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7910 0.2150 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
